# %% [markdown]
# <a href="https://colab.research.google.com/github/mohsinabul/Bank-Transaction-Fraud-Detection/blob/main/1_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparative Analysis of LiteFormer, TinyFormer, and EdgeViT-Inspired Models for Time Series Forecasting of Household Energy Consumption on Edge Devices
#
# ## Smart Meter Energy Forecasting on Edge Devices
# **Author:** Abul Mohsin
#
# **Supervisor:** Paul Moran
#
# **Date:** May 31, 2025
#
# ---
#
# ###  Objective
# Evaluate LiteFormer, TinyFormer, and EdgeViT-inspired models on:
#
# 1. Accuracy (MAE, RMSE)
#
# 2. Computational efficiency (inference time, model size)
#
# 3. Real-time performance (latency under simulated edge constraints)

# %%
import gdown
import pandas as pd

# %%
# !pip install gdown

# %%
file_id = '1zurl6uqUXqvtuDYCzHI22W7cSw1bY9Ap'
gdown.download(f'https://drive.google.com/uc?id={file_id}', 'lcl_data.csv', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1zurl6uqUXqvtuDYCzHI22W7cSw1bY9Ap
# From (redirected): https://drive.google.com/uc?id=1zurl6uqUXqvtuDYCzHI22W7cSw1bY9Ap&confirm=t&uuid=3530ece7-db9e-4ad9-b665-ed60688d4a86
# To: /content/lcl_data.csv
# 100%|██████████| 588M/588M [00:09<00:00, 64.8MB/s]
# 'lcl_data.csv'

# %%
df = pd.read_csv('lcl_data.csv')
df.head()
# Out:
#                       DateTime  MAC000002  MAC000003  MAC000004  MAC000006  \
# 0  2013-01-01 00:30:00.0000000      0.241      1.922      0.000        0.0
# 1  2013-01-01 01:00:00.0000000      0.191      1.808      0.000        0.0
# 2  2013-01-01 01:30:00.0000000      0.235      0.795      0.158        0.0
# 3  2013-01-01 02:00:00.0000000      0.182      1.235      0.000        0.0
# 4  2013-01-01 02:30:00.0000000      0.229      0.924      0.000        0.0
#
#    MAC000007  MAC000008  MAC000009  MAC000010  MAC000011  ...  MAC005555  \
# 0      0.204      0.245      0.176      0.453      0.301  ...      0.134
# 1      0.161      0.263      0.147      0.500      0.657  ...      0.090
# 2      0.214      0.261      0.093      0.621      0.683  ...      0.141
# 3      0.186      0.255      0.088      0.197      0.658  ...      0.125
# 4      0.126      0.270      0.145      0.176      0.773  ...      0.111
#
#    MAC005556  MAC005558  MAC005559  MAC005560  MAC005561  MAC005562  \
# ...

# %%
# Check basic info
df.info()

# View first few rows
df.head()

# Check missing values
df.isnull().sum().sort_values(ascending=False)

# View shape of data
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17520 entries, 0 to 17519
# Columns: 4444 entries, DateTime to MAC005567
# dtypes: float64(4443), object(1)
# memory usage: 594.0+ MB
# (17520, 4444)
